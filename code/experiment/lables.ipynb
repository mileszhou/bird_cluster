# %%
# -------------------------------------------------
# label_generator.py
# -------------------------------------------------
# Generates a label consisting of the first‑letter pinyin
# for each Chinese character in a name, followed by the
# confidence level in parentheses, e.g.   "zs (95.00%)"
# -------------------------------------------------

from __future__ import annotations
import os
import csv, sys
from typing import List
from pypinyin import lazy_pinyin, Style

# from impt import impt
# impt()

# Absolute path to the folder that contains the module
dir = os.path.abspath('./code')
if dir not in sys.path: sys.path.append(dir)
dir = os.path.abspath('./lib')
if dir not in sys.path: sys.path.append(dir)

from code.lib.label_generator import _pinyin_initials

#from code.lib.label_format import _pinyin_initials

# %%
_pinyin_initials('金丝雀')
# Out:
# 'jsq'
